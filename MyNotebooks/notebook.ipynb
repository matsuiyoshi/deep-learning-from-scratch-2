# %% [markdown]
# # 準備

# %% [markdown]
# `!python` と `%run` の違いメモ
#
# - `!python script.py` : **別プロセスとして実行**される。ノートブックとは独立して動くため、`script.py` 内で作られた変数や関数はノートブック側には残らない。
# - `%run script.py` : **同じカーネル内で実行**される。`script.py` 内で定義された変数や関数・クラスは、実行後にノートブックの後続セルからそのまま利用できる。

# %% [markdown]
# 各コードセルは **1ファイル＝1セル** の `%run` です。
#
# - 各章の先頭で `%cd ../chNN` によりその章のディレクトリに移動します（ノートブックは `MyNotebooks` 直下を想定）。
# - 続くセルでは `%run ファイル名.py` のみで実行できます。
# - プロジェクト直下でカーネルを動かしている場合は、各章の `%cd` を `chNN` に変更してください。

# %% [markdown]
# # 第1章

# %%
# %cd ../ch01

# %%
# %run forward_net.py

# %%
# %run show_spiral_dataset.py

# %%
# %run train.py

# %%
# %run train_custom_loop.py

# %%
# %run two_layer_net.py

# %% [markdown]
# # 第2章

# %%
# %cd ../ch02

# %%
# %run count_method_big.py

# %%
# %run count_method_small.py

# %%
# %run most_similar.py

# %%
# %run ppmi.py

# %%
# %run show_ptb.py

# %%
# %run similarity.py

# %% [markdown]
# # 第3章

# %%
# %cd ../ch03

# %%
# %run cbow_predict.py

# %%
# %run simple_cbow.py

# %%
# %run simple_skip_gram.py

# %%
# %run train.py

# %% [markdown]
# # 第4章

# %%
# %cd ../ch04

# %%
# %run cbow.py

# %%
# %run negative_sampling_layer.py

# %%
# %run skip_gram.py

# %%
# %run train.py

# %%
# %run eval.py

# %% [markdown]
# # 第5章

# %%
# %cd ../ch05

# %%
# %run simple_rnnlm.py

# %%
# %run train.py

# %%
# %run train_custom_loop.py

# %% [markdown]
# # 第6章

# %%
# %cd ../ch06

# %%
# %run better_rnnlm.py

# %%
# %run clip_grads.py

# %%
# %run rnn_gradient_graph.py

# %%
# %run rnnlm.py

# %%
# %run train_better_rnnlm.py

# %%
# %run train_rnnlm.py

# %%
# %run eval.py

# %% [markdown]
# # 第7章

# %%
# %cd ../ch07

# %%
# %run generate_better_text.py

# %%
# %run generate_text.py

# %%
# %run peeky_seq2seq.py

# %%
# %run rnnlm_gen.py

# %%
# %run seq2seq.py

# %%
# %run show_addition_dataset.py

# %%
# %run train_seq2seq.py

# %% [markdown]
# # 第8章

# %%
# %cd ../ch08

# %%
# %run attention_layer.py

# %%
# %run attention_seq2seq.py

# %%
# %run train.py

# %%
# %run visualize_attention.py
