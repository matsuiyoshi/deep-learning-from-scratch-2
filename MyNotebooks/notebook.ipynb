# %% [markdown]
# # 準備

# %%
# !nvidia-smi
# Out:
# Tue Mar 10 11:44:34 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone https://github.com/matsuiyoshi/deep-learning-from-scratch-2.git
# Out:
# Cloning into 'deep-learning-from-scratch-2'...
# remote: Enumerating objects: 411, done.
# remote: Counting objects: 100% (180/180), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 411 (delta 145), reused 130 (delta 130), pack-reused 231 (from 2)
# Receiving objects: 100% (411/411), 7.52 MiB | 13.72 MiB/s, done.
# Resolving deltas: 100% (240/240), done.

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# `!python` と `%run` の違いメモ
#
# - `!python script.py` : **別プロセスとして実行**される。ノートブックとは独立して動くため、`script.py` 内で作られた変数や関数はノートブック側には残らない。
# - `%run script.py` : **同じカーネル内で実行**される。`script.py` 内で定義された変数や関数・クラスは、実行後にノートブックの後続セルからそのまま利用できる。
