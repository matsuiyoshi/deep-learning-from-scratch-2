# %% [markdown]
# # 準備

# %%
# !nvidia-smi
# Out:
# Tue Mar 10 11:44:34 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !git clone https://github.com/matsuiyoshi/deep-learning-from-scratch-2.git
# Out:
# Cloning into 'deep-learning-from-scratch-2'...
# remote: Enumerating objects: 419, done.
# remote: Counting objects: 100% (188/188), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 419 (delta 148), reused 138 (delta 132), pack-reused 231 (from 2)
# Receiving objects: 100% (419/419), 7.52 MiB | 6.52 MiB/s, done.
# Resolving deltas: 100% (243/243), done.

# %%
# %cd content/deep-learning-from-scratch-2/
# !git pull

# %% [markdown]
# `!python` と `%run` の違いメモ
#
# - `!python script.py` : **別プロセスとして実行**される。ノートブックとは独立して動くため、`script.py` 内で作られた変数や関数はノートブック側には残らない。
# - `%run script.py` : **同じカーネル内で実行**される。`script.py` 内で定義された変数や関数・クラスは、実行後にノートブックの後続セルからそのまま利用できる。

# %% [markdown]
# # 第1章

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd deep-learning-from-scratch-2/ch01/
# Out:
# /content/deep-learning-from-scratch-2/ch01

# %%
# %run forward_net.py
# Out:
# [[-0.15889407  0.36751683  1.6250237 ]
#  [-0.67832213  0.29149662  1.95216661]
#  [ 0.78976957  0.00725319  2.037309  ]
#  [ 0.57336949  0.1081256   1.90554393]
#  [-0.6633677   0.17762957  2.09692897]
#  [ 0.26160796  0.16186102  1.9361184 ]
#  [ 0.31353907  0.09531118  2.03538041]
#  [ 0.04888628  0.10061017  2.07343654]
#  [-0.09645539  0.29970275  1.78165482]
#  [ 0.33791999  0.02668523  2.09763428]]
